# %% [markdown]
# ### Kurantanp Code Review

# %%
import toyplot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import bokeh.io 
from bokeh.plotting import figure
# %matplotlib inline

# Set to output the plot in the notebook
bokeh.io.output_notebook()
kwargs = {"width": 300, "height": 300}
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5c826179-d476-46d3-bf52-bfa942c54e04">Loading BokehJS ...</span>
#     </div>

# %%
N = 200
x1 = np.random.normal(10,2, size=N)
y1 = np.random.exponential(1/3, size=N)

# %%
s_plot = bokeh.plotting.figure(**kwargs)
s_plot.circle(x1, y1, size=y1)
bokeh.io.show(s_plot)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="324e3a94-d811-4e0b-8c4b-c554b3596a14"></div>
# </div>

# %% [markdown]
# ### Problem 1:
#
# **Do you think this is a useful way to emphasize information in a plot? Could it possibly be misinterpreted or misleading in some way? Did your peer create plot as instructed, and did they use the same method as you?**
#
# I could not see the plots on github for problem 1 and also could not plot them using my own notebook.

# %% [markdown]
# ### Problem 2:
#
# **Think of and describe an example scatterplot in which there are 4 values you wish to represent, and you would use size, color, and x, and y coordinates to display information about all four.**
#
# This would be a great plot for representing variables that relate to the environment/site and variables that may relate to an organism of interest. For example, the x and y could represent latitude and logitude of a pond in space, the size of the circle could represent phosphorus loading in that pond and the shading of the circle could show snail densities in the ponds.

# %% [markdown]
# ### Problem 3:
#
# **Did your peer add tick marks as described? Did they use a different method than you did?**
#
# They did place the ticks marks evenly spaced out - with 10 values in between each tick mark. There are 6 tick marks instead of 7. We both used toyplot.locator to edit the placement/count of the tick marks although I used toyplot.locator.Uniform() and they used toyplot.locator.Integer().

# %% [markdown]
# ### Problem 4:
#
# **Did your peer bin the data into 15 bins? Did they apply a colormap to the bars? Given this distribution, which type of colormap do you think would be most appropriate, i.e., a linear map, a diverging map?**
#
# Yes, the data was binned into 15 bins, the colormap was applied and the bins with the greatest height had a seperate color from the remaining bins. I think a diverging colormap would be most appropriate where the there are uniform colors on both negative and positive extremes of the histogram but the center recieves unique colors.

# %% [markdown]
# ### Problem 5:
#
# **Which of the two plots do you think is more informative about the distribution of the data? Did your peer use a different method than you did, and how do they differ?**
#
# I think the histogram with the bars on the y axis is more infromative than the scatterplot. There is a frequency of counts that provides an easier to interpret figure than the scatterplot. Our methods were basically identical where we both had the color informed by the exponential dataset.
