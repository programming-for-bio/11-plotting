# %%
# explicit import are preferred
import bokeh
import bokeh.io
import bokeh.plotting
import pandas as pd
import numpy as np

# hide warnings
import warnings
warnings.filterwarnings("ignore",category =RuntimeWarning)

# %%
# Set to output the plot in the notebook
bokeh.io.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="32167efc-28e3-4559-8d44-bf54dba1ed81">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Simple example

# %%
# prepare some data
N = 400
x = np.random.normal(0, 10, size=N)
y = x + np.random.normal(3, 8, size=N)

# %%
p = bokeh.plotting.figure(width=300, height=300)
p.circle(x, y)
bokeh.io.show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="cec27feb-4e68-4f0a-a8ef-5a6afdfe8bcb"></div>
# </div>

# %% [markdown]
# ## Fancy example

# %%
# prepare some data
N = 4000
x = np.random.random(size=N) * 100
y = np.random.random(size=N) * 100
radii = np.random.random(size=N) * 1.5
colors = [
    "#%02x%02x%02x" % (int(r), int(g), 150)
    for r, g in zip(50+2*x, 30+2*y)
]

# %%
# create a new plot with the tools above, and explicit ranges
p = bokeh.plotting.figure(
    width=400,
    height=400,
    x_range=(0, 100), 
    y_range=(0, 100))

# add a circle renderer with vectorized colors and sizes
p.circle(
    x, y, 
    radius=radii, 
    fill_color=colors, 
    fill_alpha=0.6, 
    line_color=None)

# show the results
bokeh.io.show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="b68682d9-a14f-40f8-9618-ed2aa0a3cdc9"></div>
# </div>
